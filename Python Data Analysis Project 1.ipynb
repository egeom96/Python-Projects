# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

urlretrieve('https://gist.githubusercontent.com/aakashns/28b2e504b3350afd9bdb157893f9725c/raw/994b65665757f4f8887db1c85986a897abb23d84/countries.csv', 
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x2abf825a650>)

# %%
countries_df = pd.read_csv('countries.csv')
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [raw]
# Q1: How many countries does the dataframe contain?
# Q2: Retrieve a list of continents from the dataframe?
# Q3: What is the total population of all the countries listed in this dataset?
# Q4: (Optional) What is the overall life expectancy across in the world?
# Q5: Create a dataframe containing 10 countries with the highest population.
# Q6: Add a new column in countries_df to record the overall GDP per country (product of population & per capita GDP).
# Q7: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.
# Q8: Create a data frame that counts the number countries in each continent?
# Q9: Create a data frame showing the total population of each continent.
# Q10: Count the number of countries for which the total_tests data is missing.
# Q11: Merge countries_df with covid_data_df on the location column.
# Q12: Add columns tests_per_million, cases_per_million and deaths_per_million into combined_df.
# Q13: Create a dataframe with 10 countires that have highest number of tests per million people.
# Q14: Create a dataframe with 10 countires that have highest number of positive cases per million people.
# Q15: Create a dataframe with 10 countires that have highest number of deaths cases per million people?
#
# (Optional) Q: Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".
# (Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.

# %%
#Q1: How many countries does the dataframe contain?
print(len(countries_df))

num_records = countries_df.shape[0]
print("Number of records:", num_records)
# Out:
# 210
# Number of records: 210

# %%
#Q2: Retrieve a list of continents from the dataframe?
countries_df[["continent"]]
# Out:
#     continent
# 0        Asia
# 1      Europe
# 2      Africa
# 3      Europe
# 4      Africa
# ..        ...
# 205      Asia
# 206    Africa
# 207      Asia
# 208    Africa
# 209    Africa
#
# [210 rows x 1 columns]

# %%
#Q3: What is the total population of all the countries listed in this dataset?
countries_df["population"].sum()
# Out:
# 7757980095.0

# %%
#Q4: (Optional) What is the overall life expectancy across in the world?
print("mean:",countries_df["life_expectancy"].mean())
print("median:",countries_df["life_expectancy"].median())
# Out:
# mean: 73.52985507246377
# median: 75.09

# %%
#Q5: Create a dataframe containing 10 countries with the highest population.
k=countries_df.sort_values("population",ascending=False).head(10)
k[["location","population"]]
# Out:
#           location    population
# 41           China  1.439324e+09
# 90           India  1.380004e+09
# 199  United States  3.310026e+08
# 91       Indonesia  2.735236e+08
# 145       Pakistan  2.208923e+08
# 27          Brazil  2.125594e+08
# 141        Nigeria  2.061396e+08
# 15      Bangladesh  1.646894e+08
# 157         Russia  1.459345e+08
# 125         Mexico  1.289328e+08

# %%
#Q6: Add a new column in countries_df to record the overall GDP per country (product of population & per capita GDP).

for index,row in countries_df.iterrows():
    countries_df.at[index,"Overall GDP"]=row["population"]*row["gdp_per_capita"]

# %%
countries_df.sort_values("Overall GDP",ascending=False)
# Out:
#                          location      continent    population  \
# 41                          China           Asia  1.439324e+09
# 199                 United States  North America  3.310026e+08
# 90                          India           Asia  1.380004e+09
# 99                          Japan           Asia  1.264765e+08
# 73                        Germany         Europe  8.378394e+07
# ..                            ...            ...           ...
# 185                        Taiwan           Asia  2.381678e+07
# 194      Turks and Caicos Islands  North America  3.871800e+04
# 200  United States Virgin Islands  North America  1.044230e+05
# 203                       Vatican         Europe  8.090000e+02
# 206                Western Sahara         Africa  5.973300e+05
#
#      life_expectancy  hospital_beds_per_thousand  gdp_per_capita   Overall GDP
# 41             76.91                        4.34       15308.712  2.203419e+13
# ...

# %% [raw]
# Q7: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita,
# among the counties with population greater than 100 million.

# %%
countries_df[countries_df["population"]>100000000].sort_values("gdp_per_capita").head(10)
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita   Overall GDP
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %%
#Q8: Create a data frame that counts the number countries in each continent?
k=countries_df.groupby("continent")["location"].count()
l=pd.DataFrame(k)
l
# Out:
#                location
# continent
# Africa               55
# Asia                 47
# Europe               51
# North America        36
# Oceania               8
# South America        13

# %%
#Q9: Create a data frame showing the total population of each continent.
m=countries_df.groupby("continent")["population"].sum()
pd.DataFrame(m)
# Out:
#                  population
# continent
# Africa         1.339424e+09
# Asia           4.607388e+09
# Europe         7.485062e+08
# North America  5.912425e+08
# Oceania        4.095832e+07
# South America  4.304611e+08

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/b2a968a6cfd9fbbb0ff3d6bd0f26262b/raw/b115ed1dfa17f10fc88bf966236cd4d9032f1df8/covid-countries-data.csv', 
            'covid-countries-data.csv')
covid_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_df.head()
# Out:
#       location  total_cases  total_deaths  total_tests
# 0  Afghanistan      38243.0        1409.0          NaN
# 1      Albania       9728.0         296.0          NaN
# 2      Algeria      45158.0        1525.0          NaN
# 3      Andorra       1199.0          53.0          NaN
# 4       Angola       2729.0         109.0          NaN

# %%
#Q10: Count the number of countries for which the total_tests data is missing.
a=covid_df[covid_df["total_tests"].isna()]
a[["location"]].count()
# Out:
# location    122
# dtype: int64

# %%
#Q11: Merge countries_df with covid_data_df on the location column.
merged_df=covid_df.merge(countries_df,on="location")
merged_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
#Q12: Add columns tests_per_million, cases_per_million and deaths_per_million into combined_df.

for index,row in merged_df.iterrows():
    merged_df.at[index,"tests_per_million"]=row["total_tests"]/row["population"]*1000000
    merged_df.at[index,"cases_per_million"]=row["total_cases"]/row["population"]*1000000
    merged_df.at[index,"deaths_per_million"]=row["total_deaths"]/row["population"]*1000000

# %%
#13-14-15 Create a dataframe with 10 countires that have highest number of tests,deaths and cases per million people.
a =merged_df.sort_values("tests_per_million",ascending=False).head(10)
a
# Out:
#                  location  total_cases  total_deaths  total_tests  \
# 197  United Arab Emirates      71540.0         387.0    7177430.0
# 14                Bahrain      52440.0         190.0    1118837.0
# 115            Luxembourg       7928.0         124.0     385820.0
# 122                 Malta       1931.0          13.0     188539.0
# 53                Denmark      17195.0         626.0    2447911.0
# 96                 Israel     122539.0         969.0    2353984.0
# 89                Iceland       2121.0          10.0      88829.0
# 157                Russia    1005000.0       17414.0   37176827.0
# 199         United States    6114406.0      185744.0   83898416.0
# 10              Australia      25923.0         663.0    6255797.0
#
#          continent   population  life_expectancy  hospital_beds_per_thousand  \
# 197           Asia    9890400.0            77.97                       1.200
# 14            Asia    1701583.0            77.29                       2.000
# ...

# %%
b=merged_df.sort_values("cases_per_million",ascending=False).head(10)
b
# Out:
#           location  total_cases  total_deaths  total_tests      continent  \
# 155          Qatar     119206.0         199.0     634745.0           Asia
# 14         Bahrain      52440.0         190.0    1118837.0           Asia
# 147         Panama      94084.0        2030.0     336345.0  North America
# 40           Chile     414739.0       11344.0    2458762.0  South America
# 162     San Marino        735.0          42.0          NaN         Europe
# 9            Aruba       2211.0          12.0          NaN  North America
# 105         Kuwait      86478.0         535.0     621616.0           Asia
# 150           Peru     663437.0       29259.0     584232.0  South America
# 27          Brazil    3997865.0      123780.0    4797948.0  South America
# 199  United States    6114406.0      185744.0   83898416.0  North America
#
#       population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
c=merged_df.sort_values("deaths_per_million",ascending=False).head(10)
c
# Out:
#            location  total_cases  total_deaths  total_tests      continent  \
# 162      San Marino        735.0          42.0          NaN         Europe
# 150            Peru     663437.0       29259.0     584232.0  South America
# 18          Belgium      85817.0        9898.0    2281853.0         Europe
# 3           Andorra       1199.0          53.0          NaN         Europe
# 177           Spain     479554.0       29194.0    6416533.0         Europe
# 198  United Kingdom     338676.0       41514.0   13447568.0         Europe
# 40            Chile     414739.0       11344.0    2458762.0  South America
# 97            Italy     271515.0       35497.0    5214766.0         Europe
# 27           Brazil    3997865.0      123780.0    4797948.0  South America
# 182          Sweden      84532.0        5820.0          NaN         Europe
#
#       population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
#(Optional) Q: Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".

count=0

for index_a,row_a in a.iterrows():
    for index_b,row_b in b.iterrows():
        if a.at[index_a,"location"]==b.at[index_b,"location"]:
            count=count+1
        else:
            count
            
print(count)
# Out:
# 2

# %% [raw]
# #(Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.

# %%
merged_df.head()
lowest_gdp=merged_df.sort_values("gdp_per_capita").head(20)
lowest_gdp
# Out:
#                          location  total_cases  total_deaths  total_tests  \
# 38       Central African Republic       4712.0          62.0          NaN
# 32                        Burundi        448.0           1.0          NaN
# 111                       Liberia       1305.0          82.0          NaN
# 52   Democratic Republic of Congo      10113.0         258.0          NaN
# 140                         Niger       1177.0          69.0          NaN
# 118                        Malawi       5579.0         175.0          NaN
# 132                    Mozambique       4117.0          25.0          NaN
# 168                  Sierra Leone       2029.0          71.0          NaN
# 43                        Comoros        427.0           7.0          NaN
# 117                    Madagascar      15023.0         196.0          NaN
# 190                          Togo       1434.0          30.0      54709.0
# 207                         Yemen       1976.0         571.0          NaN
# ...

# %%
lowest_hospital=merged_df.sort_values("hospital_beds_per_thousand").head(20)
lowest_hospital
# Out:
#          location  total_cases  total_deaths  total_tests      continent  \
# 121          Mali       2802.0         126.0          NaN         Africa
# 117    Madagascar      15023.0         196.0          NaN         Africa
# 82         Guinea       9479.0          59.0          NaN         Africa
# 63       Ethiopia      54409.0         846.0     869430.0         Africa
# 135         Nepal      41649.0         251.0     705560.0           Asia
# 140         Niger       1177.0          69.0          NaN         Africa
# 31   Burkina Faso       1378.0          55.0          NaN         Africa
# 0     Afghanistan      38243.0        1409.0          NaN           Asia
# 195        Uganda       3112.0          32.0     381749.0         Africa
# 20          Benin       2194.0          40.0          NaN         Africa
# 90          India    3853406.0       67376.0   44337201.0           Asia
# 145      Pakistan     297014.0        6328.0    2662508.0           Asia
# ...

# %% [markdown]
# #(Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.

# %%
count=0

for index_a,row_a in lowest_gdp.iterrows():
    for index_b,row_b in lowest_hospital.iterrows():
        if lowest_gdp.at[index_a,"location"]==lowest_hospital.at[index_b,"location"]:
            count=count+1
        else:
            count
print("number of countries that feature in both the lists 20 countries with lowest GDP per capita and 20 countries with the lowest number of hospital beds per thousand population:",count)
# Out:
# number of countries that feature in both the lists 20 countries with lowest GDP per capita and 20 countries with the lowest number of hospital beds per thousand population: 10
